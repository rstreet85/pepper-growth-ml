# %%
import pandas

annuum_raw = pandas.read_csv('annuum_raw.csv')
annuum_raw.plot(kind='scatter', x='Days_to_maturity', y='Gddc_total', c='Label')
# Out:
# <Axes: xlabel='Days_to_maturity', ylabel='Gddc_total'>
